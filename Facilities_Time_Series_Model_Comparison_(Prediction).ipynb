# %% [markdown]
# <a href="https://colab.research.google.com/github/djlittle/Facilities-Time-Series-Model-Comparison/blob/master/Facilities_Time_Series_Model_Comparison_(Prediction).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Imports

import pandas as pd
import numpy as np
import operator
import time
import datetime
import re

from scipy import stats

from statsmodels.tsa.statespace.sarimax import SARIMAX

print('Imports completed successfully')
# Out:
# Imports completed successfully

# %%
# ----- General options -------
min_wos = 20
min_topic_volume = 5

# ----- User output options -------
verbose = True
print_processing_time = True
print_size = 5
n_print_terms = 20

# ----- Statistical distribution option(s) -------
topic_alpha = 0.1
confidence = 0.95

# ----- SARIMAX model options(s) ----------------
forecast_weeks = 3

# %%
# Data load

url = 'https://raw.githubusercontent.com/djlittle/Facilities-Time-Series-Model-Comparison/master/Data/Topic_Time_Series_Data.csv'

count_by_week = pd.read_csv(url)

print(count_by_week.head())
# Out:
#    Week of Year  Topic 1  Topic 2  Topic 3  ...  Topic 7  Topic 8  Topic 9  Topic 10
# 0             2        0        0        0  ...        0        0        0         0
# 1             3        0        1        0  ...        0        0        1         1
# 2             4        0        1        1  ...        0        0        0         2
# 3             5        0        0        0  ...        1        1        2         2
# 4             6        0        0        1  ...        1        0        0         1
#
# [5 rows x 11 columns]

# %%
count_by_week    # Displaying the dataframe
# Out:
#     Week of Year  Topic 1  Topic 2  ...  Topic 8  Topic 9  Topic 10
# 0              2        0        0  ...        0        0         0
# 1              3        0        1  ...        0        1         1
# 2              4        0        1  ...        0        0         2
# 3              5        0        0  ...        1        2         2
# 4              6        0        0  ...        0        0         1
# 5              7        0        2  ...        1        0         2
# 6              8        1       10  ...        2        0         1
# 7              9        3        7  ...        6        2         4
# 8             10        5        2  ...        2        2         8
# 9             11        1        6  ...        4        7         7
# 10            12        2        4  ...        4        5         5
# 11            13        3        8  ...        1        3         2
# 12            14        0        0  ...        4        0         4
# 13            15        1        3  ...        4       11         7
# 14            16        2        5  ...        3        7         3
# 15            17        1        1  ...        3        3         1
# 16            18        0        7  ...        0        3         2
# 17            19        1        3  ...        2        5         1
# 18            20        1        4  ...        3        3         1
# 19            21        0        4  ...        1        2         6
# 20            22        2        4  ...        2        1         2
# 21            23        0        2  ...        1        3         6
# 22            24        2        6  ...        3        6         1
# 23            25        0        1  ...        2        4         0
# 24            26        1        4  ...        3        3         3
# 25            27        0        1  ...        3        8         6
# 26            28        0        0  ...        4        3         4
# 27            29        0        0  ...        0        1         4
# 28            30        0        0  ...        1        3         1
# 29            31        2        1  ...        4        1         3
# 30            32        2        1  ...        1        3         0
# 31            33        1        3  ...        1        1         1
# 32            34        0        6  ...        2        2         3
# 33            35        1        3  ...        1        3         1
# 34            36        1        2  ...        0        4         2
# 35            37        1        1  ...        1        1         0
# 36            38        0        2  ...        2        4         1
# 37            39        2        2  ...        2        6         6
# 38            40        1        1  ...        3        2         4
# 39            41        2        2  ...        2        1         3
# 40            42        0        3  ...        1        1         2
# 41            43        1        3  ...        2        0         3
# 42            44        5        3  ...        0        1         3
# 43            45        3        4  ...        1        1         1
# 44            46        1        0  ...        0        2         0
# 45            47        2        4  ...        8        2         6
# 46            48        2        7  ...        7        3         5
# 47            49        9        2  ...        6        1         8
# 48            50        1        0  ...        1        5         4
# 49            51        3        2  ...        6        4         2
# 50            52        1        4  ...        3        3         1
#
# [51 rows x 11 columns]

# %%
forecast_df = pd.DataFrame()

topic_forecast_accuracy = []
modeled_topics = []
for topic in count_by_week.columns[1:]:
  # Model fitting
  # ***Options here are to be explored
  if count_by_week[topic].sum() < min_topic_volume: # Removing extremely low volume occurances 
      continue

  modeled_topics.append(topic)
  sarimax = SARIMAX(count_by_week[topic], order=(2, 0, 0), seasonal_order=(1, 1, 1, 4))

  try:
      sarimax_fit = sarimax.fit(disp=False)
  except:
      sarimax_fit = sarimax.fit(disp=False, start_params=[0, 0, 0, 0, 1])

  if verbose:
      # print(yhat)
      print(sarimax_fit.summary())

  # ----------------------- Error estimate ---------------------------------------------------------
  res = sarimax.filter(sarimax_fit.params)
  predict = res.get_prediction()
  predict_mean = predict.predicted_mean
  predict_mean[predict_mean < 0] = 0.00001  # removing erronious negative values
  topic_cbw = count_by_week[topic]
  residuals = predict_mean - topic_cbw
  error = abs(residuals)[6:]/(topic_cbw[6:].mean())
  percent_error = ((error - error.min()) / (error.max() - error.min())).mean()
  topic_forecast_accuracy.append(1-percent_error)

  if forecast_df.empty:
    continue

#   convert forcast accuracy to an array
topic_forecast_accuracy = np.asanyarray(topic_forecast_accuracy)
# Out:
#                                  Statespace Model Results
# =========================================================================================
# Dep. Variable:                           Topic 1   No. Observations:                   51
# Model:             SARIMAX(2, 0, 0)x(1, 1, 1, 4)   Log Likelihood                 -91.231
# Date:                           Tue, 28 Jan 2020   AIC                            192.462
# Time:                                   21:22:03   BIC                            201.713
# Sample:                                        0   HQIC                           195.943
#                                             - 51
# Covariance Type:                             opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.1013      0.235      0.432      0.666      -0.359       0.561
# ar.L2          0.2052      0.438      0.468      0.639      -0.653       1.064
# ar.S.L4        0.1328      0.506      0.262      0.793      -0.859       1.125
# ma.S.L4       -0.6932      0.533     -1.300      0.194      -1.739       0.352
# sigma2         2.7280      0.367      7.428      0.000       2.008       3.448
# ===================================================================================
# Ljung-Box (Q):                       31.65   Jarque-Bera (JB):                72.28
# Prob(Q):                              0.82   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.69   Skew:                             1.79
# Prob(H) (two-sided):                  0.30   Kurtosis:                         7.90
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                  Statespace Model Results
# =========================================================================================
# Dep. Variable:                           Topic 2   No. Observations:                   51
# Model:             SARIMAX(2, 0, 0)x(1, 1, 1, 4)   Log Likelihood                -111.404
# Date:                           Tue, 28 Jan 2020   AIC                            232.807
# Time:                                   21:22:03   BIC                            242.058
# Sample:                                        0   HQIC                           236.288
#                                             - 51
# Covariance Type:                             opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.1659      0.137      1.209      0.227      -0.103       0.435
# ar.L2          0.1220      0.189      0.644      0.520      -0.249       0.493
# ar.S.L4        0.0726      0.229      0.318      0.751      -0.375       0.521
# ma.S.L4       -0.9997     94.120     -0.011      0.992    -185.471     183.471
# sigma2         5.4633    513.759      0.011      0.992   -1001.486    1012.413
# ===================================================================================
# Ljung-Box (Q):                       30.89   Jarque-Bera (JB):                 5.79
# Prob(Q):                              0.85   Prob(JB):                         0.06
# Heteroskedasticity (H):               0.29   Skew:                             0.79
# Prob(H) (two-sided):                  0.02   Kurtosis:                         3.66
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                  Statespace Model Results
# =========================================================================================
# Dep. Variable:                           Topic 3   No. Observations:                   51
# Model:             SARIMAX(2, 0, 0)x(1, 1, 1, 4)   Log Likelihood                -143.702
# Date:                           Tue, 28 Jan 2020   AIC                            297.404
# Time:                                   21:22:03   BIC                            306.655
# Sample:                                        0   HQIC                           300.885
#                                             - 51
# Covariance Type:                             opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.8656      0.081     10.677      0.000       0.707       1.025
# ar.L2         -0.2957      0.106     -2.798      0.005      -0.503      -0.089
# ar.S.L4        0.1262      0.208      0.607      0.544      -0.281       0.533
# ma.S.L4       -0.9997    214.699     -0.005      0.996    -421.802     419.802
# sigma2        21.3041   4571.712      0.005      0.996   -8939.087    8981.695
# ===================================================================================
# Ljung-Box (Q):                       16.32   Jarque-Bera (JB):                14.82
# Prob(Q):                              1.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.08   Skew:                             0.88
# Prob(H) (two-sided):                  0.00   Kurtosis:                         5.12
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                  Statespace Model Results
# =========================================================================================
# Dep. Variable:                           Topic 4   No. Observations:                   51
# Model:             SARIMAX(2, 0, 0)x(1, 1, 1, 4)   Log Likelihood                -162.161
# Date:                           Tue, 28 Jan 2020   AIC                            334.322
# Time:                                   21:22:04   BIC                            343.573
# Sample:                                        0   HQIC                           337.803
#                                             - 51
# Covariance Type:                             opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.4464      0.287      1.554      0.120      -0.117       1.009
# ar.L2          0.0397      0.190      0.209      0.834      -0.332       0.411
# ar.S.L4       -0.2630      0.106     -2.479      0.013      -0.471      -0.055
# ma.S.L4       -0.6346      0.221     -2.873      0.004      -1.067      -0.202
# sigma2        53.7319      8.749      6.142      0.000      36.584      70.879
# ===================================================================================
# Ljung-Box (Q):                       23.04   Jarque-Bera (JB):               108.18
# Prob(Q):                              0.99   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.29   Skew:                             1.58
# Prob(H) (two-sided):                  0.02   Kurtosis:                         9.73
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                  Statespace Model Results
# =========================================================================================
# Dep. Variable:                           Topic 5   No. Observations:                   51
# Model:             SARIMAX(2, 0, 0)x(1, 1, 1, 4)   Log Likelihood                -127.981
# Date:                           Tue, 28 Jan 2020   AIC                            265.962
# Time:                                   21:22:04   BIC                            275.213
# Sample:                                        0   HQIC                           269.443
#                                             - 51
# Covariance Type:                             opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.0863      0.289     -0.299      0.765      -0.653       0.480
# ar.L2         -0.1598      0.233     -0.686      0.492      -0.616       0.296
# ar.S.L4       -0.1033      0.195     -0.530      0.596      -0.485       0.279
# ma.S.L4       -0.7500      0.232     -3.236      0.001      -1.204      -0.296
# sigma2        12.4869      2.277      5.484      0.000       8.024      16.950
# ===================================================================================
# Ljung-Box (Q):                       33.25   Jarque-Bera (JB):                83.33
# Prob(Q):                              0.77   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.21   Skew:                            -1.62
# Prob(H) (two-sided):                  0.00   Kurtosis:                         8.66
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                  Statespace Model Results
# =========================================================================================
# Dep. Variable:                           Topic 6   No. Observations:                   51
# Model:             SARIMAX(2, 0, 0)x(1, 1, 1, 4)   Log Likelihood                -164.614
# Date:                           Tue, 28 Jan 2020   AIC                            339.228
# Time:                                   21:22:04   BIC                            348.479
# Sample:                                        0   HQIC                           342.709
#                                             - 51
# Covariance Type:                             opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.4159      0.155      2.686      0.007       0.112       0.719
# ar.L2         -0.1087      0.187     -0.580      0.562      -0.476       0.258
# ar.S.L4       -0.0643      0.170     -0.378      0.705      -0.398       0.269
# ma.S.L4       -0.9991     58.546     -0.017      0.986    -115.747     113.749
# sigma2        51.2345   2995.976      0.017      0.986   -5820.771    5923.240
# ===================================================================================
# Ljung-Box (Q):                       19.70   Jarque-Bera (JB):               351.51
# Prob(Q):                              1.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.15   Skew:                             2.74
# Prob(H) (two-sided):                  0.00   Kurtosis:                        15.22
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                  Statespace Model Results
# =========================================================================================
# Dep. Variable:                           Topic 7   No. Observations:                   51
# Model:             SARIMAX(2, 0, 0)x(1, 1, 1, 4)   Log Likelihood                -121.062
# Date:                           Tue, 28 Jan 2020   AIC                            252.124
# Time:                                   21:22:04   BIC                            261.375
# Sample:                                        0   HQIC                           255.605
#                                             - 51
# Covariance Type:                             opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.3809      0.128      2.976      0.003       0.130       0.632
# ar.L2          0.2359      0.171      1.382      0.167      -0.099       0.570
# ar.S.L4       -0.0304      0.205     -0.148      0.882      -0.432       0.372
# ma.S.L4       -0.9993     65.837     -0.015      0.988    -130.037     128.038
# sigma2         8.1410    535.195      0.015      0.988   -1040.822    1057.104
# ===================================================================================
# Ljung-Box (Q):                       27.31   Jarque-Bera (JB):                 1.79
# Prob(Q):                              0.94   Prob(JB):                         0.41
# Heteroskedasticity (H):               0.24   Skew:                             0.42
# Prob(H) (two-sided):                  0.01   Kurtosis:                         2.54
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                  Statespace Model Results
# =========================================================================================
# Dep. Variable:                           Topic 8   No. Observations:                   51
# Model:             SARIMAX(2, 0, 0)x(1, 1, 1, 4)   Log Likelihood                 -98.190
# Date:                           Tue, 28 Jan 2020   AIC                            206.380
# Time:                                   21:22:05   BIC                            215.630
# Sample:                                        0   HQIC                           209.861
#                                             - 51
# Covariance Type:                             opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.3038      0.125      2.439      0.015       0.060       0.548
# ar.L2          0.1662      0.149      1.119      0.263      -0.125       0.457
# ar.S.L4       -0.0203      0.375     -0.054      0.957      -0.756       0.715
# ma.S.L4       -0.7818      0.418     -1.871      0.061      -1.601       0.037
# sigma2         3.5173      0.620      5.672      0.000       2.302       4.733
# ===================================================================================
# Ljung-Box (Q):                       28.13   Jarque-Bera (JB):                 5.02
# Prob(Q):                              0.92   Prob(JB):                         0.08
# Heteroskedasticity (H):               1.46   Skew:                             0.57
# Prob(H) (two-sided):                  0.45   Kurtosis:                         4.12
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                  Statespace Model Results
# =========================================================================================
# Dep. Variable:                           Topic 9   No. Observations:                   51
# Model:             SARIMAX(2, 0, 0)x(1, 1, 1, 4)   Log Likelihood                -105.086
# Date:                           Tue, 28 Jan 2020   AIC                            220.173
# Time:                                   21:22:05   BIC                            229.424
# Sample:                                        0   HQIC                           223.654
#                                             - 51
# Covariance Type:                             opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.3200      0.155      2.065      0.039       0.016       0.624
# ar.L2          0.0860      0.225      0.382      0.703      -0.355       0.527
# ar.S.L4        0.1249      0.170      0.735      0.462      -0.208       0.458
# ma.S.L4       -0.8586      0.282     -3.045      0.002      -1.411      -0.306
# sigma2         4.6579      1.196      3.895      0.000       2.314       7.002
# ===================================================================================
# Ljung-Box (Q):                       41.48   Jarque-Bera (JB):                 8.73
# Prob(Q):                              0.41   Prob(JB):                         0.01
# Heteroskedasticity (H):               0.43   Skew:                             0.66
# Prob(H) (two-sided):                  0.10   Kurtosis:                         4.64
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                  Statespace Model Results
# =========================================================================================
# Dep. Variable:                          Topic 10   No. Observations:                   51
# Model:             SARIMAX(2, 0, 0)x(1, 1, 1, 4)   Log Likelihood                -102.822
# Date:                           Tue, 28 Jan 2020   AIC                            215.644
# Time:                                   21:22:05   BIC                            224.895
# Sample:                                        0   HQIC                           219.125
#                                             - 51
# Covariance Type:                             opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.4894      0.147      3.326      0.001       0.201       0.778
# ar.L2         -0.1366      0.147     -0.930      0.352      -0.425       0.151
# ar.S.L4       -0.2645      0.205     -1.290      0.197      -0.666       0.137
# ma.S.L4       -0.9989     39.582     -0.025      0.980     -78.578      76.580
# sigma2         3.5668    141.109      0.025      0.980    -273.001     280.135
# ===================================================================================
# Ljung-Box (Q):                       41.47   Jarque-Bera (JB):                 1.38
# Prob(Q):                              0.41   Prob(JB):                         0.50
# Heteroskedasticity (H):               0.73   Skew:                             0.42
# Prob(H) (two-sided):                  0.54   Kurtosis:                         2.92
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
print(topic_forecast_accuracy) # Each topic forecast accuracy
print(topic_forecast_accuracy.mean()) # Aggregate forecast accuracy
# Out:
# [0.84043335 0.77308153 0.80652674 0.89202314 0.87632625 0.89046228
#  0.69837861 0.76764473 0.78371851 0.74775994]
# 0.8076355078677031
